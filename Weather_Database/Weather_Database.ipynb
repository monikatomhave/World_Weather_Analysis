# %%
# import the dependancies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# output is a zip object in the memory, zip object packs each pair having the same index
# in their respective array into a tuple. These can be accesses by the index of 0 and 1,
# latitude and longitude respectively.

# %%
# add the latitudes and longitudes to a list

# you can only unzip a zipped tuple once before it is erased from the computer's memory.
# always make sure you unzip the lats and longs into the coordinates list before moving on

coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
#Import the time library and the timedate module from the datetime library

import time
from datetime import datetime

# %%
# Import the request library.

import requests

# Import the API key.

from config import weather_api_key

url ="https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# create an empty list to hold the weather data

city_data = []

#print the beginning of the logging.

print("Beginning Data Retrieval          ")
print("----------------------------------")


# create counters.

record_count = 1
set_count = 1

# Loop through all the cities in the list. Using enumerate() method
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    # check remainder of index divided by 50 is 0, and if index is greater than
    # 50, if true then set count and record count are incremented by 1.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.  Here we are also removing the blank
    # spaces in the city name and concatinating the city name.  This will find
    # the corresopnding weather data for the city instead of finding the weather data
    # for the first part of the city name.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.  Printing counts and 
    # tells us which city is being processed
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        # "pass" is used as a general purpose statement to handle all errors encountered
        # and allows the program to continue.
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------------
# Processing Record 1 of Set 1 | challans
# Processing Record 2 of Set 1 | victoria
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | lasa
# Processing Record 5 of Set 1 | sur
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | bubaque
# Processing Record 10 of Set 1 | dongsheng
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | cockburn town
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 1 | sitka
# Processing Record 17 of Set 1 | erenhot
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | oga
# Processing Record 22 of Set 1 | santa isabel
# Processing Record 23 of Set 1 | cayenne
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 1 | knyaze-volkonskoye
# Processing Record 27 of Set 1 | kieta
# Processing Record 28 of Set 1 | keti bandar
# Processing Record 29 of Set 1 | filadelfia
# Processing Record 30 of Set 1 | necochea
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | vila franca do campo
# Processing Record 33 of Set 1 | cangzhou
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | kahului
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | nanjing
# Processing Record 39 of Set 1 | krivosheino
# Processing Record 40 of Set 1 | bousso
# Processing Record 41 of Set 1 | chokurdakh
# Processing Record 42 of Set 1 | kutum
# Processing Record 43 of Set 1 | whitehorse
# Processing Record 44 of Set 1 | saint anthony
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | galveston
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | waingapu
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | berbera
# Processing Record 7 of Set 2 | murdochville
# Processing Record 8 of Set 2 | asau
# Processing Record 9 of Set 2 | korla
# Processing Record 10 of Set 2 | pitimbu
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | cortez
# Processing Record 14 of Set 2 | oum hadjer
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | pilao arcado
# City not found. Skipping...
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | adrar
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | lexington
# Processing Record 23 of Set 2 | tuatapere
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | lodja
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | abu dhabi
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | alice springs
# Processing Record 31 of Set 2 | coahuayana
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | kumasi
# Processing Record 35 of Set 2 | urengoy
# Processing Record 36 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 2 | odesskoye
# Processing Record 38 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 2 | hearst
# Processing Record 40 of Set 2 | kargasok
# Processing Record 41 of Set 2 | yershov
# Processing Record 42 of Set 2 | ewa beach
# Processing Record 43 of Set 2 | pitea
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | leningradskiy
# Processing Record 46 of Set 2 | hilo
# Processing Record 47 of Set 2 | pekan
# Processing Record 48 of Set 2 | kavieng
# Processing Record 49 of Set 2 | caravelas
# Processing Record 50 of Set 2 | tual
# Processing Record 1 of Set 3 | ayagoz
# Processing Record 2 of Set 3 | souillac
# Processing Record 3 of Set 3 | mount gambier
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | faya
# Processing Record 6 of Set 3 | talnakh
# Processing Record 7 of Set 3 | geraldton
# Processing Record 8 of Set 3 | bumbesti-jiu
# Processing Record 9 of Set 3 | decatur
# Processing Record 10 of Set 3 | bathsheba
# Processing Record 11 of Set 3 | hukuntsi
# Processing Record 12 of Set 3 | jiangyou
# Processing Record 13 of Set 3 | kuznechikha
# Processing Record 14 of Set 3 | vilhena
# Processing Record 15 of Set 3 | nemuro
# Processing Record 16 of Set 3 | tucuma
# Processing Record 17 of Set 3 | butaritari
# Processing Record 18 of Set 3 | corn island
# Processing Record 19 of Set 3 | maragogi
# Processing Record 20 of Set 3 | santander
# Processing Record 21 of Set 3 | sao filipe
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | verkhnyaya inta
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | beyneu
# Processing Record 26 of Set 3 | port elizabeth
# Processing Record 27 of Set 3 | gerede
# Processing Record 28 of Set 3 | noyabrsk
# Processing Record 29 of Set 3 | kidal
# Processing Record 30 of Set 3 | hermanus
# Processing Record 31 of Set 3 | minsk
# Processing Record 32 of Set 3 | padang
# Processing Record 33 of Set 3 | khrebtovaya
# Processing Record 34 of Set 3 | lavrentiya
# Processing Record 35 of Set 3 | mahajanga
# Processing Record 36 of Set 3 | yining
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | namatanai
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | tura
# Processing Record 41 of Set 3 | san lorenzo de el escorial
# Processing Record 42 of Set 3 | la romana
# Processing Record 43 of Set 3 | alofi
# Processing Record 44 of Set 3 | tateyama
# Processing Record 45 of Set 3 | qaanaaq
# Processing Record 46 of Set 3 | innisfail
# Processing Record 47 of Set 3 | simao
# Processing Record 48 of Set 3 | altay
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 50 of Set 3 | hithadhoo
# Processing Record 1 of Set 4 | lorengau
# Processing Record 2 of Set 4 | severo-kurilsk
# Processing Record 3 of Set 4 | tuktoyaktuk
# Processing Record 4 of Set 4 | carutapera
# Processing Record 5 of Set 4 | kasur
# Processing Record 6 of Set 4 | makat
# Processing Record 7 of Set 4 | vitim
# Processing Record 8 of Set 4 | luderitz
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | bozuyuk
# Processing Record 11 of Set 4 | buala
# Processing Record 12 of Set 4 | bredasdorp
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | iqaluit
# Processing Record 15 of Set 4 | taltal
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | maniitsoq
# Processing Record 18 of Set 4 | mwingi
# Processing Record 19 of Set 4 | gamba
# Processing Record 20 of Set 4 | launceston
# Processing Record 21 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 4 | port blair
# Processing Record 23 of Set 4 | ugep
# Processing Record 24 of Set 4 | bandarbeyla
# Processing Record 25 of Set 4 | constitucion
# Processing Record 26 of Set 4 | canoinhas
# Processing Record 27 of Set 4 | sao joao da barra
# Processing Record 28 of Set 4 | pacific grove
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | poum
# Processing Record 32 of Set 4 | evensk
# Processing Record 33 of Set 4 | mersing
# Processing Record 34 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 35 of Set 4 | bani walid
# Processing Record 36 of Set 4 | bollnas
# Processing Record 37 of Set 4 | mananjary
# Processing Record 38 of Set 4 | kijang
# Processing Record 39 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 4 | modasa
# Processing Record 41 of Set 4 | imeni poliny osipenko
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | carlsbad
# Processing Record 44 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 4 | lumby
# Processing Record 46 of Set 4 | bonthe
# Processing Record 47 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 4 | college
# Processing Record 49 of Set 4 | saint-augustin
# Processing Record 50 of Set 4 | leshukonskoye
# Processing Record 1 of Set 5 | grindavik
# Processing Record 2 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 5 | dunedin
# Processing Record 4 of Set 5 | puerto baquerizo moreno
# Processing Record 5 of Set 5 | cherskiy
# Processing Record 6 of Set 5 | narsaq
# Processing Record 7 of Set 5 | laguna
# Processing Record 8 of Set 5 | pimentel
# Processing Record 9 of Set 5 | yulara
# Processing Record 10 of Set 5 | kudahuvadhoo
# Processing Record 11 of Set 5 | nara
# Processing Record 12 of Set 5 | grand forks
# Processing Record 13 of Set 5 | henties bay
# Processing Record 14 of Set 5 | pevek
# Processing Record 15 of Set 5 | honiara
# Processing Record 16 of Set 5 | tarakan
# Processing Record 17 of Set 5 | grand-santi
# Processing Record 18 of Set 5 | keetmanshoop
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 21 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 5 | baruun-urt
# Processing Record 23 of Set 5 | makubetsu
# Processing Record 24 of Set 5 | luba
# Processing Record 25 of Set 5 | gbarnga
# Processing Record 26 of Set 5 | meadow lake
# Processing Record 27 of Set 5 | estelle
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | garissa
# Processing Record 30 of Set 5 | san carlos del zulia
# Processing Record 31 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 5 | palmer
# Processing Record 33 of Set 5 | general pico
# Processing Record 34 of Set 5 | san patricio
# Processing Record 35 of Set 5 | san marcos
# Processing Record 36 of Set 5 | safaga
# Processing Record 37 of Set 5 | cape coast
# Processing Record 38 of Set 5 | borovoy
# Processing Record 39 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 5 | canora
# Processing Record 41 of Set 5 | tiksi
# Processing Record 42 of Set 5 | miyako
# Processing Record 43 of Set 5 | ilulissat
# Processing Record 44 of Set 5 | nanortalik
# Processing Record 45 of Set 5 | ha tinh
# Processing Record 46 of Set 5 | camopi
# Processing Record 47 of Set 5 | kerteh
# City not found. Skipping...
# Processing Record 48 of Set 5 | bambous virieux
# Processing Record 49 of Set 5 | minot
# Processing Record 50 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 6 | verkhoyansk
# Processing Record 2 of Set 6 | shimoda
# Processing Record 3 of Set 6 | meulaboh
# Processing Record 4 of Set 6 | ebano
# City not found. Skipping...
# Processing Record 5 of Set 6 | labuhan
# Processing Record 6 of Set 6 | hobyo
# Processing Record 7 of Set 6 | karachi
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 6 | kaitangata
# Processing Record 11 of Set 6 | vestmannaeyjar
# Processing Record 12 of Set 6 | clyde river
# Processing Record 13 of Set 6 | bac lieu
# Processing Record 14 of Set 6 | husavik
# Processing Record 15 of Set 6 | sri aman
# Processing Record 16 of Set 6 | kununurra
# Processing Record 17 of Set 6 | vila velha
# Processing Record 18 of Set 6 | valdosta
# Processing Record 19 of Set 6 | ailigandi
# Processing Record 20 of Set 6 | endicott
# Processing Record 21 of Set 6 | katangli
# Processing Record 22 of Set 6 | ostrovnoy
# Processing Record 23 of Set 6 | yeppoon
# Processing Record 24 of Set 6 | guerrero negro
# Processing Record 25 of Set 6 | beeville
# Processing Record 26 of Set 6 | kalmunai
# Processing Record 27 of Set 6 | marsa matruh
# Processing Record 28 of Set 6 | nurota
# Processing Record 29 of Set 6 | srednekolymsk
# Processing Record 30 of Set 6 | bacolod
# Processing Record 31 of Set 6 | jardim
# Processing Record 32 of Set 6 | jiuquan
# Processing Record 33 of Set 6 | westport
# Processing Record 34 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 35 of Set 6 | longyearbyen
# Processing Record 36 of Set 6 | betanzos
# Processing Record 37 of Set 6 | fort-shevchenko
# Processing Record 38 of Set 6 | kruisfontein
# Processing Record 39 of Set 6 | monte alegre
# Processing Record 40 of Set 6 | coihaique
# Processing Record 41 of Set 6 | broken hill
# Processing Record 42 of Set 6 | port lincoln
# Processing Record 43 of Set 6 | pangnirtung
# Processing Record 44 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 6 | staryy nadym
# Processing Record 46 of Set 6 | beloha
# Processing Record 47 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 6 | saskylakh
# Processing Record 49 of Set 6 | vostok
# Processing Record 50 of Set 6 | canutama
# Processing Record 1 of Set 7 | svetlyy
# Processing Record 2 of Set 7 | ahipara
# Processing Record 3 of Set 7 | ofaqim
# Processing Record 4 of Set 7 | lima
# Processing Record 5 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 7 | quang ngai
# Processing Record 7 of Set 7 | chicama
# Processing Record 8 of Set 7 | almaznyy
# Processing Record 9 of Set 7 | chumikan
# Processing Record 10 of Set 7 | celestun
# Processing Record 11 of Set 7 | xiongzhou
# Processing Record 12 of Set 7 | ancud
# Processing Record 13 of Set 7 | koryazhma
# Processing Record 14 of Set 7 | kachiry
# Processing Record 15 of Set 7 | sovetsk
# Processing Record 16 of Set 7 | mahaicony
# City not found. Skipping...
# Processing Record 17 of Set 7 | fortuna
# Processing Record 18 of Set 7 | camana
# Processing Record 19 of Set 7 | mayumba
# Processing Record 20 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 7 | ugra
# Processing Record 23 of Set 7 | dwarka
# Processing Record 24 of Set 7 | chor
# Processing Record 25 of Set 7 | oussouye
# Processing Record 26 of Set 7 | provost
# Processing Record 27 of Set 7 | asyut
# Processing Record 28 of Set 7 | dondo
# Processing Record 29 of Set 7 | guiglo
# Processing Record 30 of Set 7 | ugoofaaru
# Processing Record 31 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 7 | flinders
# Processing Record 34 of Set 7 | goianesia
# Processing Record 35 of Set 7 | amapa
# Processing Record 36 of Set 7 | bonavista
# Processing Record 37 of Set 7 | cozumel
# Processing Record 38 of Set 7 | vanimo
# Processing Record 39 of Set 7 | punta de piedra
# Processing Record 40 of Set 7 | pisco
# Processing Record 41 of Set 7 | cairns
# Processing Record 42 of Set 7 | itarema
# Processing Record 43 of Set 7 | lata
# Processing Record 44 of Set 7 | mattru
# Processing Record 45 of Set 7 | qaqortoq
# Processing Record 46 of Set 7 | barrow
# Processing Record 47 of Set 7 | khartoum
# Processing Record 48 of Set 7 | borger
# Processing Record 49 of Set 7 | lebu
# Processing Record 50 of Set 7 | lagoa
# Processing Record 1 of Set 8 | movila
# Processing Record 2 of Set 8 | hambantota
# Processing Record 3 of Set 8 | bengkulu
# Processing Record 4 of Set 8 | dingle
# Processing Record 5 of Set 8 | bosaso
# Processing Record 6 of Set 8 | kaeo
# Processing Record 7 of Set 8 | yunyang
# Processing Record 8 of Set 8 | manokwari
# Processing Record 9 of Set 8 | broome
# Processing Record 10 of Set 8 | sambava
# Processing Record 11 of Set 8 | rutul
# Processing Record 12 of Set 8 | paranhos
# Processing Record 13 of Set 8 | naze
# Processing Record 14 of Set 8 | hami
# Processing Record 15 of Set 8 | faanui
# Processing Record 16 of Set 8 | cidreira
# Processing Record 17 of Set 8 | vardo
# Processing Record 18 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 19 of Set 8 | santa cruz de tenerife
# Processing Record 20 of Set 8 | port hardy
# Processing Record 21 of Set 8 | sehithwa
# Processing Record 22 of Set 8 | oyon
# Processing Record 23 of Set 8 | banda aceh
# Processing Record 24 of Set 8 | durban
# Processing Record 25 of Set 8 | lompoc
# Processing Record 26 of Set 8 | teya
# Processing Record 27 of Set 8 | abu samrah
# Processing Record 28 of Set 8 | simplicio mendes
# Processing Record 29 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 8 | hirara
# Processing Record 31 of Set 8 | pringsewu
# Processing Record 32 of Set 8 | rawalpindi
# Processing Record 33 of Set 8 | mtama
# Processing Record 34 of Set 8 | karratha
# Processing Record 35 of Set 8 | kapoeta
# Processing Record 36 of Set 8 | maldonado
# Processing Record 37 of Set 8 | nyagan
# Processing Record 38 of Set 8 | kimparana
# Processing Record 39 of Set 8 | bereda
# Processing Record 40 of Set 8 | gimli
# Processing Record 41 of Set 8 | saurimo
# Processing Record 42 of Set 8 | touros
# Processing Record 43 of Set 8 | mazamari
# Processing Record 44 of Set 8 | san cristobal
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | mnogovershinnyy
# Processing Record 47 of Set 8 | eydhafushi
# Processing Record 48 of Set 8 | klitos
# Processing Record 49 of Set 8 | tahe
# Processing Record 50 of Set 8 | qiongshan
# Processing Record 1 of Set 9 | kota bahru
# Processing Record 2 of Set 9 | olinda
# Processing Record 3 of Set 9 | vilyuysk
# Processing Record 4 of Set 9 | vitimskiy
# City not found. Skipping...
# Processing Record 5 of Set 9 | nishihara
# Processing Record 6 of Set 9 | belyy yar
# Processing Record 7 of Set 9 | oistins
# Processing Record 8 of Set 9 | half moon bay
# Processing Record 9 of Set 9 | tonj
# Processing Record 10 of Set 9 | hamilton
# Processing Record 11 of Set 9 | karpathos
# Processing Record 12 of Set 9 | chuy
# Processing Record 13 of Set 9 | finschhafen
# Processing Record 14 of Set 9 | price
# Processing Record 15 of Set 9 | mehamn
# Processing Record 16 of Set 9 | saint-leu
# Processing Record 17 of Set 9 | beringovskiy
# Processing Record 18 of Set 9 | flin flon
# Processing Record 19 of Set 9 | manaure
# Processing Record 20 of Set 9 | caxito
# Processing Record 21 of Set 9 | nyurba
# Processing Record 22 of Set 9 | nosy varika
# Processing Record 23 of Set 9 | carbonear
# Processing Record 24 of Set 9 | tabukiniberu
# City not found. Skipping...
# Processing Record 25 of Set 9 | vestmanna
# Processing Record 26 of Set 9 | houma
# Processing Record 27 of Set 9 | aripuana
# Processing Record 28 of Set 9 | roma
# Processing Record 29 of Set 9 | yerbogachen
# Processing Record 30 of Set 9 | khandyga
# Processing Record 31 of Set 9 | huarmey
# Processing Record 32 of Set 9 | abu jubayhah
# City not found. Skipping...
# Processing Record 33 of Set 9 | mirador
# Processing Record 34 of Set 9 | darnah
# Processing Record 35 of Set 9 | abalak
# Processing Record 36 of Set 9 | loharu
# Processing Record 37 of Set 9 | nassau
# Processing Record 38 of Set 9 | makambako
# Processing Record 39 of Set 9 | blackfoot
# Processing Record 40 of Set 9 | sarkand
# Processing Record 41 of Set 9 | ambam
# Processing Record 42 of Set 9 | fort nelson
# Processing Record 43 of Set 9 | batagay-alyta
# Processing Record 44 of Set 9 | sao felix do xingu
# Processing Record 45 of Set 9 | abashiri
# Processing Record 46 of Set 9 | saint paul
# Processing Record 47 of Set 9 | bertoua
# Processing Record 48 of Set 9 | denpasar
# Processing Record 49 of Set 9 | lagos de moreno
# Processing Record 50 of Set 9 | rocha
# Processing Record 1 of Set 10 | kamenka
# Processing Record 2 of Set 10 | mansa
# Processing Record 3 of Set 10 | corinto
# Processing Record 4 of Set 10 | schroeder
# Processing Record 5 of Set 10 | beckley
# Processing Record 6 of Set 10 | belmonte
# Processing Record 7 of Set 10 | eureka
# Processing Record 8 of Set 10 | haines junction
# Processing Record 9 of Set 10 | ambon
# Processing Record 10 of Set 10 | hare bay
# Processing Record 11 of Set 10 | gat
# Processing Record 12 of Set 10 | abeche
# Processing Record 13 of Set 10 | bemidji
# Processing Record 14 of Set 10 | camocim
# Processing Record 15 of Set 10 | fare
# Processing Record 16 of Set 10 | shagamu
# Processing Record 17 of Set 10 | nikki
# Processing Record 18 of Set 10 | san quintin
# Processing Record 19 of Set 10 | marawi
# Processing Record 20 of Set 10 | katesh
# Processing Record 21 of Set 10 | karonga
# Processing Record 22 of Set 10 | moron
# Processing Record 23 of Set 10 | mazagao
# Processing Record 24 of Set 10 | cabedelo
# Processing Record 25 of Set 10 | dayong
# Processing Record 26 of Set 10 | port-gentil
# Processing Record 27 of Set 10 | primorsk
# Processing Record 28 of Set 10 | colares
# Processing Record 29 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 10 | honningsvag
# Processing Record 31 of Set 10 | kavaratti
# Processing Record 32 of Set 10 | leh
# Processing Record 33 of Set 10 | berlevag
# Processing Record 34 of Set 10 | coquimbo
# Processing Record 35 of Set 10 | sao paulo de olivenca
# Processing Record 36 of Set 10 | ulladulla
# Processing Record 37 of Set 10 | avera
# Processing Record 38 of Set 10 | plouzane
# Processing Record 39 of Set 10 | nago
# Processing Record 40 of Set 10 | moerai
# Processing Record 41 of Set 10 | makakilo city
# Processing Record 42 of Set 10 | xai-xai
# Processing Record 43 of Set 10 | buchanan
# Processing Record 44 of Set 10 | chenghai
# Processing Record 45 of Set 10 | markala
# Processing Record 46 of Set 10 | saint george
# Processing Record 47 of Set 10 | gornopravdinsk
# Processing Record 48 of Set 10 | marsabit
# Processing Record 49 of Set 10 | nuevo progreso
# Processing Record 50 of Set 10 | macieira de cambra
# Processing Record 1 of Set 11 | tieling
# Processing Record 2 of Set 11 | hovd
# Processing Record 3 of Set 11 | kayes
# Processing Record 4 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 11 | trat
# Processing Record 6 of Set 11 | abastumani
# Processing Record 7 of Set 11 | samarai
# Processing Record 8 of Set 11 | marrakesh
# Processing Record 9 of Set 11 | lazaro cardenas
# Processing Record 10 of Set 11 | bhatapara
# Processing Record 11 of Set 11 | mehran
# Processing Record 12 of Set 11 | virginia beach
# Processing Record 13 of Set 11 | dezful
# Processing Record 14 of Set 11 | batagay
# Processing Record 15 of Set 11 | okhotsk
# Processing Record 16 of Set 11 | acarau
# Processing Record 17 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 11 | brahmapuri
# City not found. Skipping...
# Processing Record 19 of Set 11 | telimele
# Processing Record 20 of Set 11 | myingyan
# Processing Record 21 of Set 11 | severo-yeniseyskiy
# Processing Record 22 of Set 11 | dryden
# Processing Record 23 of Set 11 | kulhudhuffushi
# Processing Record 24 of Set 11 | eagle pass
# Processing Record 25 of Set 11 | ratnagiri
# Processing Record 26 of Set 11 | bentiu
# Processing Record 27 of Set 11 | sayyan
# Processing Record 28 of Set 11 | kitimat
# Processing Record 29 of Set 11 | katobu
# Processing Record 30 of Set 11 | iquitos
# Processing Record 31 of Set 11 | batemans bay
# Processing Record 32 of Set 11 | pocone
# Processing Record 33 of Set 11 | bilma
# Processing Record 34 of Set 11 | taoudenni
# Processing Record 35 of Set 11 | bintulu
# Processing Record 36 of Set 11 | xiangdong
# City not found. Skipping...
# Processing Record 37 of Set 11 | teluknaga
# Processing Record 38 of Set 11 | portland
# Processing Record 39 of Set 11 | serenje
# Processing Record 40 of Set 11 | ponta delgada
# Processing Record 41 of Set 11 | the valley
# Processing Record 42 of Set 11 | vao
# Processing Record 43 of Set 11 | ardakan
# Processing Record 44 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 11 | nabire
# Processing Record 46 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 47 of Set 11 | tecoanapa
# Processing Record 48 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 49 of Set 11 | tessalit
# Processing Record 50 of Set 11 | oksfjord
# Processing Record 1 of Set 12 | marabba
# Processing Record 2 of Set 12 | kelowna
# Processing Record 3 of Set 12 | bartica
# Processing Record 4 of Set 12 | egvekinot
# Processing Record 5 of Set 12 | urucara
# Processing Record 6 of Set 12 | yantal
# Processing Record 7 of Set 12 | elko
# Processing Record 8 of Set 12 | seymchan
# Processing Record 9 of Set 12 | tornio
# Processing Record 10 of Set 12 | goedereede
# Processing Record 11 of Set 12 | luohe
# Processing Record 12 of Set 12 | bria
# Processing Record 13 of Set 12 | pontianak
# Processing Record 14 of Set 12 | rawah
# Processing Record 15 of Set 12 | nampula
# Processing Record 16 of Set 12 | gubkinskiy
# Processing Record 17 of Set 12 | hammerfest
# Processing Record 18 of Set 12 | huanan
# Processing Record 19 of Set 12 | hirado
# Processing Record 20 of Set 12 | zakopane
# Processing Record 21 of Set 12 | port augusta
# Processing Record 22 of Set 12 | ho
# City not found. Skipping...
# Processing Record 23 of Set 12 | camacha
# Processing Record 24 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 12 | fukue
# Processing Record 26 of Set 12 | dibulla
# Processing Record 27 of Set 12 | cabo san lucas
# Processing Record 28 of Set 12 | derzhavinsk
# Processing Record 29 of Set 12 | sakakah
# Processing Record 30 of Set 12 | soria
# Processing Record 31 of Set 12 | santa helena de goias
# Processing Record 32 of Set 12 | kroya
# Processing Record 33 of Set 12 | ngorongoro
# Processing Record 34 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 35 of Set 12 | akdagmadeni
# Processing Record 36 of Set 12 | nexo
# Processing Record 37 of Set 12 | progreso
# Processing Record 38 of Set 12 | umm lajj
# Processing Record 39 of Set 12 | kumo
# Processing Record 40 of Set 12 | ukiah
# Processing Record 41 of Set 12 | ljubimec
# City not found. Skipping...
# Processing Record 42 of Set 12 | mayo
# Processing Record 43 of Set 12 | wanaka
# Processing Record 44 of Set 12 | dinghai
# Processing Record 45 of Set 12 | la ronge
# Processing Record 46 of Set 12 | okha
# Processing Record 47 of Set 12 | staraya russa
# Processing Record 48 of Set 12 | dzaoudzi
# Processing Record 49 of Set 12 | arandis
# Processing Record 50 of Set 12 | mayabon
# Processing Record 1 of Set 13 | san pedro
# Processing Record 2 of Set 13 | black diamond
# Processing Record 3 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 5 of Set 13 | winfield
# Processing Record 6 of Set 13 | kenitra
# Processing Record 7 of Set 13 | quatre cocos
# Processing Record 8 of Set 13 | ushtobe
# Processing Record 9 of Set 13 | stara vyzhivka
# Processing Record 10 of Set 13 | sayabec
# City not found. Skipping...
# Processing Record 11 of Set 13 | eucaliptus
# Processing Record 12 of Set 13 | vindeby
# Processing Record 13 of Set 13 | rincon
# Processing Record 14 of Set 13 | akdepe
# Processing Record 15 of Set 13 | kumbo
# Processing Record 16 of Set 13 | bara
# Processing Record 17 of Set 13 | belaya gora
# Processing Record 18 of Set 13 | buraydah
# Processing Record 19 of Set 13 | kos
# Processing Record 20 of Set 13 | ilhabela
# Processing Record 21 of Set 13 | muros
# Processing Record 22 of Set 13 | petrovskoye
# Processing Record 23 of Set 13 | waddan
# Processing Record 24 of Set 13 | semporna
# Processing Record 25 of Set 13 | bjornevatn
# Processing Record 26 of Set 13 | popondetta
# Processing Record 27 of Set 13 | taloqan
# Processing Record 28 of Set 13 | antalaha
# Processing Record 29 of Set 13 | jacareacanga
# Processing Record 30 of Set 13 | bonnyville
# Processing Record 31 of Set 13 | san jeronimo
# Processing Record 32 of Set 13 | ust-omchug
# Processing Record 33 of Set 13 | rochester
# Processing Record 34 of Set 13 | khatassy
# Processing Record 35 of Set 13 | la crosse
# Processing Record 36 of Set 13 | nanakuli
# Processing Record 37 of Set 13 | shenjiamen
# Processing Record 38 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 13 | tecpan
# Processing Record 40 of Set 13 | puro
# Processing Record 41 of Set 13 | cocula
# Processing Record 42 of Set 13 | thinadhoo
# Processing Record 43 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 13 | ambovombe
# Processing Record 45 of Set 13 | nador
# Processing Record 46 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 13 | merauke
# Processing Record 48 of Set 13 | murgab
# Processing Record 49 of Set 13 | tarko-sale
# Processing Record 50 of Set 13 | asosa
# Processing Record 1 of Set 14 | san ramon
# Processing Record 2 of Set 14 | anori
# Processing Record 3 of Set 14 | turayf
# Processing Record 4 of Set 14 | finnsnes
# Processing Record 5 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 14 | parras
# City not found. Skipping...
# Processing Record 7 of Set 14 | xam nua
# Processing Record 8 of Set 14 | goderich
# Processing Record 9 of Set 14 | zeya
# Processing Record 10 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 14 | valparaiso
# Processing Record 12 of Set 14 | soverato
# Processing Record 13 of Set 14 | kailua
# Processing Record 14 of Set 14 | kishi
# Processing Record 15 of Set 14 | renqiu
# Processing Record 16 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 17 of Set 14 | lincoln
# Processing Record 18 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 19 of Set 14 | lusambo
# Processing Record 20 of Set 14 | nuuk
# Processing Record 21 of Set 14 | nelson
# Processing Record 22 of Set 14 | nocrich
# Processing Record 23 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 24 of Set 14 | diphu
# Processing Record 25 of Set 14 | baykit
# Processing Record 26 of Set 14 | rio gallegos
# Processing Record 27 of Set 14 | mount pleasant
# Processing Record 28 of Set 14 | morristown
# Processing Record 29 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 30 of Set 14 | samana
# Processing Record 31 of Set 14 | kuybysheve
# Processing Record 32 of Set 14 | xuanwu
# Processing Record 33 of Set 14 | raozan
# City not found. Skipping...
# Processing Record 34 of Set 14 | borba
# Processing Record 35 of Set 14 | rodniki
# Processing Record 36 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 14 | yafran
# Processing Record 38 of Set 14 | seydi
# Processing Record 39 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 14 | arlit
# Processing Record 41 of Set 14 | ialisos
# City not found. Skipping...
# Processing Record 42 of Set 14 | qandala
# Processing Record 43 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 44 of Set 14 | aksu
# Processing Record 45 of Set 14 | sept-iles
# Processing Record 46 of Set 14 | sao domingos
# Processing Record 47 of Set 14 | kathmandu
# Processing Record 48 of Set 14 | dinahican
# Processing Record 49 of Set 14 | zharkent
# Processing Record 50 of Set 14 | coihueco
# Processing Record 1 of Set 15 | limon
# Processing Record 2 of Set 15 | baijiantan
# Processing Record 3 of Set 15 | praya
# Processing Record 4 of Set 15 | gualeguay
# Processing Record 5 of Set 15 | ostersund
# Processing Record 6 of Set 15 | acapulco
# Processing Record 7 of Set 15 | griffith
# Processing Record 8 of Set 15 | pires do rio
# Processing Record 9 of Set 15 | bam
# Processing Record 10 of Set 15 | tabas
# Processing Record 11 of Set 15 | matay
# Processing Record 12 of Set 15 | barra do garcas
# Processing Record 13 of Set 15 | araouane
# Processing Record 14 of Set 15 | nizhniy kuranakh
# Processing Record 15 of Set 15 | tolaga bay
# Processing Record 16 of Set 15 | homer
# Processing Record 17 of Set 15 | gumushane
# City not found. Skipping...
# Processing Record 18 of Set 15 | jasper
# Processing Record 19 of Set 15 | horsham
# Processing Record 20 of Set 15 | usakos
# Processing Record 21 of Set 15 | bom jardim
# Processing Record 22 of Set 15 | yanji
# Processing Record 23 of Set 15 | jalu
# Processing Record 24 of Set 15 | altoona
# Processing Record 25 of Set 15 | rock springs
# Processing Record 26 of Set 15 | visnes
# Processing Record 27 of Set 15 | krasnogvardeyskiy
# Processing Record 28 of Set 15 | aberdeen
# Processing Record 29 of Set 15 | southampton
# Processing Record 30 of Set 15 | umm bab
# Processing Record 31 of Set 15 | bushehr
# Processing Record 32 of Set 15 | mwaya
# Processing Record 33 of Set 15 | boende
# Processing Record 34 of Set 15 | koslan
# Processing Record 35 of Set 15 | the pas
# Processing Record 36 of Set 15 | trairi
# Processing Record 37 of Set 15 | guira de melena
# Processing Record 38 of Set 15 | danilovka
# Processing Record 39 of Set 15 | boralday
# Processing Record 40 of Set 15 | udachnyy
# Processing Record 41 of Set 15 | hofn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 670

# %%
# Convert by creating a df

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Challans  46.8436   -1.8749     71.80        76          82
# 1      Victoria  22.2855  114.1577     84.38        86          96
# 2       Rikitea -23.1203 -134.9692     73.76        75          54
# 3          Lasa  46.6166   10.7002     63.48        92          73
# 4           Sur  22.5667   59.5289     90.84        57          99
# 5      Thompson  55.7435  -97.8558     71.76        68          75
# 6        Torbay  47.6666  -52.7314     62.76        95         100
# 7  Puerto Ayora  -0.7393  -90.3518     75.16        89          97
# 8       Bubaque  11.2833  -15.8333     80.40        79          41
# 9     Dongsheng  39.8161  109.9776     67.80        47          34
#
#    Wind Speed Country Current Description
# 0       17.18      FR       broken clouds
# 1        5.99      HK     overcast clouds
# 2       18.63      PF          light rain
# 3        3.40      IT       broken clouds
# 4       15.50      OM     overcast clouds
# 5       13.80      CA       broken clouds
# 6        5.75      CA                mist
# 7        5.01      EC     overcast clouds
# 8       17.90      GW    scattered clouds
# 9       12.12      CN    scattered clouds

# %%
# Reorder the columns in the order we want them to appear

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Challans      FR  46.8436   -1.8749     71.80        76          82
# 1      Victoria      HK  22.2855  114.1577     84.38        86          96
# 2       Rikitea      PF -23.1203 -134.9692     73.76        75          54
# 3          Lasa      IT  46.6166   10.7002     63.48        92          73
# 4           Sur      OM  22.5667   59.5289     90.84        57          99
# 5      Thompson      CA  55.7435  -97.8558     71.76        68          75
# 6        Torbay      CA  47.6666  -52.7314     62.76        95         100
# 7  Puerto Ayora      EC  -0.7393  -90.3518     75.16        89          97
# 8       Bubaque      GW  11.2833  -15.8333     80.40        79          41
# 9     Dongsheng      CN  39.8161  109.9776     67.80        47          34
#
#    Wind Speed Current Description
# 0       17.18       broken clouds
# 1        5.99     overcast clouds
# 2       18.63          light rain
# 3        3.40       broken clouds
# 4       15.50     overcast clouds
# 5       13.80       broken clouds
# 6        5.75                mist
# 7        5.01     overcast clouds
# 8       17.90    scattered clouds
# 9       12.12    scattered clouds

# %%
# create the output file (csv)

#output_data_file = "Weather_Database/WeatherPy_Database.csv"
output_data_file = "WeatherPy_Database.csv"


# Export the City_Data into the CSV

city_data_df.to_csv(output_data_file, index_label = "City_ID")
